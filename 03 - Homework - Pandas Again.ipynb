# %% [markdown]
# ### Homework Instructions:
#
# For every exercise below, run code in the code blocks after each question and display answers by running the code. Do not use the `print()` statement, simply put dataframe at the bottom of your code block when you run it.
#
# For example, if the exercise asked you to create a list called `my_list`, you would create it and run the block below

# %%
my_list = [1, 6, 3]
my_list
# Out:
# [1, 6, 3]

# %% [markdown]
# Notice that the code above displays the output without the `print()` statement. This output format will be easier for us to utilize in this class.

# %% [markdown]
# ### Using pandas
#
# The data is located at: https://foco-ds-portal-files.s3.amazonaws.com/chicken_weights.csv
#
# This data represents weights of different chickens by week. Chicks are on different diets.
#
# The columns in the data represent:
#
# `weight`: the weight of the chick
# `Time`: the week the chick weight was measured
# `Chick`: the chick being measured (each individual chicken)
# `Diet`: the type of diet the chick was fed. This is a categorical variable 1, 2, 3, 4. These represent different types of feed (i.e. bone meal, feather meal, etc.)
#
# Create a new dataframe and read in the dataset from the URL above. Call your new dataframe "wts" and display the first 5 rows.

# %% [markdown]
# ##### Exercise 1

# %%
# Out:
#    weight  Time  Chick  Diet
# 0      42     0      1     1
# 1      51     2      1     1
# 2      59     4      1     1
# 3      64     6      1     1
# 4      76     8      1     1

# %% [markdown]
# ##### Exercise 2
#
# Change all column names to lowercase, then show the first 5 rows to ensure the names are lowercase.

# %%
# Out:
#    weight  time  chick  diet
# 0      42     0      1     1
# 1      51     2      1     1
# 2      59     4      1     1
# 3      64     6      1     1
# 4      76     8      1     1

# %% [markdown]
# ##### Exercise 3
#
# Filter data where:
#   -  diet of either 1 or 4
#   -  AND time of 0
#
# Do not create a new dataframe.

# %%
# Out:
#      weight  time  chick  diet
# 460      42     0     41     4
# 472      42     0     42     4
# 484      42     0     43     4
# 496      42     0     44     4
# 506      41     0     45     4
# 518      40     0     46     4
# 530      41     0     47     4
# 542      39     0     48     4
# 554      40     0     49     4
# 566      41     0     50     4

# %% [markdown]
# ##### Exercise 4
#
# A histogram can be useful to identify the distribution of data. We will get into distributions later in the course. However, let's take a quick look at the data using the `.plot.hist` method.
#
# Create a histogram of the weights of all chicks. Use the default settings for plotting.

# %% [markdown]
# ##### Exercise 5
#
# Due to the fact that `weight` is recorded each week, it doesn't make sense to plot all of them in a histogram. Recreate the plot but filter the data for the time equal to 20.

# %% [markdown]
# ##### Exercise 6
#
# Recreate the same plot, but change the `bins` parameter to 20.

# %% [markdown]
# ##### Exercise 7
#
# A `density` plot can be used in a similar fashion to a histogram. Create the previous plot, but instead of using `.hist` use the `.density` method.

# %% [markdown]
# ##### Exercise 8
#
# Create the previous density plot again with one twist. Make 4 separate density plots in the same frame but one with different colors for each line (overlayed on top of one another). These 4 separate lines should each represent one of the `diet` types.
#
# You can achieve this by filtering the data and calling the plotting functions one after another. The
#
# ```
# my_dataframe[filtered_condition_1].plot.my_plot_type()
# my_dataframe[filtered_condition_2].plot.my_plot_type()
# my_dataframe[filtered_condition_3].plot.my_plot_type()
# my_dataframe[filtered_condition_4].plot.my_plot_type()
# ```
