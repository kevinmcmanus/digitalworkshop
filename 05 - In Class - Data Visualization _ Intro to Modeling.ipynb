# %% [markdown]
# # Python - Data Visualization

# %% [markdown]
# ### Section 1 - Data Vizualization Recap
#
# We will be using another dataset from the `seaborn` package. It is the "diamonds" dataset.

# %% [markdown]
# ##### Exercise 1
#
# Import pandas and seaborn (use the shortcut names)

# %%
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ##### Exercise 2
#
# The dataset is loaded into a DataFrame called `diamonds`
#
# The columns represent diamond features:
#
# *  price: price in US dollars (\$326--\$18,823)
# *  carat: weight of the diamond (0.2--5.01)
# *  cut: quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# *  color diamond colour, from J (worst) to D (best)
# *  clarity: a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# *  x: length in mm (0--10.74)
# *  y: width in mm (0--58.9)
# *  z: depth in mm (0--31.8)
# *  depth: total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
# *  table: width of top of diamond relative to widest point (43--95)
#
#
# **Show the last 10 rows of the data.**

# %%
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53930   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
# 53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53934   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %% [markdown]
# ##### Exercise 3
#
# Create a `pairplot` of the dataframe

# %% [markdown]
# ##### Exercise 4
#
# Comment on anything you would want to look into in more depth from the chart above.

# %% [markdown]
# **Add your response here**

# %% [markdown]
# ##### Exercise 5
#
# Create a plot to look into what you wrote about in Exercise 4 (above).

# %% [markdown]
# ##### Exercise 6
#
# Create line plots of `carat` vs `price` separated into rows by `cut`

# %% [markdown]
# ##### Exercise 7
#
# Do you think the relationship between carat and price is linear? Explain.

# %% [markdown]
# ***Answer here***

# %% [markdown]
# ### Section 2 - Data Visualization Libraries
#
# Explore multiple libraries, find the ones that fit your use case.
#
# https://www.analyticsvidhya.com/blog/2020/03/6-data-visualization-python-libraries/
#
# (my personal favorite is Altair: https://altair-viz.github.io/index.html )
#
#
# For the following exercises, use the iris dataset loaded in the next block. Your data will be called `iris`

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ##### Exercise 1
#
# Create a scatterplot of sepal_length vs. sepal_width and color by species. In each code block you will use a different library

# %%
# https://seaborn.pydata.org/
import seaborn as sns

# %%
# https://altair-viz.github.io/index.html
import altair as alt
# Out:
# alt.Chart(...)

# %%
# https://plotly.com/python/
import plotly.express as px
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="aadee0cc-0719-44fe-a57c-7a2d3fc90ee2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aadee0cc-0719-44fe-a57c-7a2d3fc90ee2")) {
#                     Plotly.newPlot(
#                         'aadee0cc-0719-44fe-a57c-7a2d3fc90ee2',
# ...

# %%
# https://plotnine.readthedocs.io/en/stable/
from plotnine import ggplot, geom_point, aes
# Out:
# <ggplot: (8789526261042)>

# %%
# https://docs.bokeh.org/en/latest/index.html
from bokeh.plotting import figure, show, output_notebook
# Out:
#   <div class="bk-root" id="5ee49ef7-febd-4a39-b348-9cde50286ab2" data-root-id="1362"></div>

# %%
# https://matplotlib.org/3.2.1/contents.html
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Exercise 2
#
# Choose one of the previous plotting libraries and make 2 more charts of any type from the `iris` dataset.

# %%
# Chart 1

# %%
# Chart 2

# %% [markdown]
# ### Section 3 - Modeling Basics

# %% [markdown]
# ##### Exercise 1
#
# Create a new variable called `data` from your `iris` dataset. Filter your data so that it only contains 2 species: setosa & virginica. Select only the columns: species, sepal_length, petal_length
#
# Display the first 3 rows.

# %%
# Out:
#   species  sepal_length  petal_length
# 0  setosa           5.1           1.4
# 1  setosa           4.9           1.4
# 2  setosa           4.7           1.3

# %% [markdown]
# ##### Exercise 2
# Create a scatterplot of your data based off of `sepal_length` and `petal_length` with `species` as colors. Utilize the `altair` library.

# %%
# Out:
# alt.Chart(...)

# %% [markdown]
# ##### Exercise 3
#
# Create a line that splits the speices using sepal_length and petal_length.
#
# Use the standard format we all learned in school:
#
# "y = mx + b"
#
# "petal_length = m * sepal_length + b"
#
# You should achieve this by creating a new column labeled "model". You will likely have to iterate through a number of options and continue to graph until you find a value that fits. It doesn't have to be optimized, but should split the data into 2 groups.
#
# Create the "model" and display the same scatter chart above but add a line for the model.

# %%
# Out:
# alt.LayerChart(...)
