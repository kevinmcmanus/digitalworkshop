# %% [markdown]
# Setup is done for you. For ALL plotting exercises use the `seaborn` library.

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset('mpg')
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#     mpg  cylinders  displacement  ...  model_year  origin                       name
# 0  18.0          8         307.0  ...          70     usa  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...          70     usa          buick skylark 320
# 2  18.0          8         318.0  ...          70     usa         plymouth satellite
# 3  16.0          8         304.0  ...          70     usa              amc rebel sst
# 4  17.0          8         302.0  ...          70     usa                ford torino
#
# [5 rows x 9 columns]

# %% [markdown]
# #### Exercise 1
#
# Show how weight data is distributed.
#
# Hint: use `.distplot` -- note that `.distplot` does not accept a dataframe for data. You need to pass in ONLY the price column.

# %% [markdown]
# #### Exercise 2
#
# Comment on what the chart above tells you about your data.

# %% [markdown]
# ***Write your answer in this text block***

# %% [markdown]
# #### Exercise 3
#
# Create a scatterplot to show relationship between weight and acceleration. You should accompany this with histograms alongside of each axis.
#
# This sounds daunting, but it is only one line in `seaborn`!
#
# Hint: use `.jointplot`

# %% [markdown]
# #### Exercise 4
#
# Comment on what the chart above tells you about your data

# %% [markdown]
# ***Write your answer in this text block***

# %% [markdown]
# #### Exercise 5
#
# Create a plot that you think is interesting or meaningful from the data, then, describe what you see in it.
