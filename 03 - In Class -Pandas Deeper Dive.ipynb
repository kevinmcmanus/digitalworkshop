# %% [markdown]
# # Pandas - Deeper Dive

# %% [markdown]
# ### Section 1 - Quick Look at Your Data

# %% [markdown]
# ##### Exercise 1
#
# Import the required library and create DataFrame from CSV at:
#
# https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv
#
# Your new DataFrame should be a variable called `nba`

# %% [markdown]
# ##### Exercise 2
#
# *   Display the first 4 rows of `nba`
# *   Display the last 10 rows of `nba`

# %%
# Out:
#    gameorder       game_id lg_id  ...  game_result  forecast notes
# 0          1  194611010TRH   NBA  ...            L  0.640065   NaN
# 1          1  194611010TRH   NBA  ...            W  0.359935   NaN
# 2          2  194611020CHS   NBA  ...            W  0.631101   NaN
# 3          2  194611020CHS   NBA  ...            L  0.368899   NaN
#
# [4 rows x 23 columns]

# %%
# Out:
#         gameorder       game_id lg_id  ...  game_result  forecast notes
# 126304      63153  201506070GSW   NBA  ...            W  0.242326   NaN
# 126305      63153  201506070GSW   NBA  ...            L  0.757674   NaN
# 126306      63154  201506090CLE   NBA  ...            L  0.472157   NaN
# 126307      63154  201506090CLE   NBA  ...            W  0.527843   NaN
# 126308      63155  201506110CLE   NBA  ...            W  0.453428   NaN
# 126309      63155  201506110CLE   NBA  ...            L  0.546572   NaN
# 126310      63156  201506140GSW   NBA  ...            W  0.765565   NaN
# 126311      63156  201506140GSW   NBA  ...            L  0.234435   NaN
# 126312      63157  201506170CLE   NBA  ...            L  0.481450   NaN
# 126313      63157  201506170CLE   NBA  ...            W  0.518550   NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# ##### Exercise 3
#
# What are the dimensions of `nba` (rows and width)?
#
# Hint, a dataframe has the `.shape` attribute

# %%
# Out:
# (126314, 23)

# %% [markdown]
# ##### Exercise 4
#
# Show all column data types of `nba`
#
# Hint, a dataframe has the `.info` method

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# ##### Exercise 5
#
# Show basic summary stats of `nba` (count, mean, ..., etc.)
#
# Hint, a dataframe has the `.describe` method

# %%
# Out:
#            gameorder        _iscopy  ...      opp_elo_n       forecast
# count  126314.000000  126314.000000  ...  126314.000000  126314.000000
# mean    31579.000000       0.500000  ...    1495.236055       0.500000
# std     18231.927643       0.500002  ...     112.461687       0.215252
# min         1.000000       0.000000  ...    1085.774400       0.020447
# 25%     15790.000000       0.000000  ...    1416.994900       0.327989
# 50%     31579.000000       0.500000  ...    1500.954400       0.500000
# 75%     47368.000000       1.000000  ...    1576.291625       0.672011
# max     63157.000000       1.000000  ...    1853.104500       0.979553
#
# [8 rows x 13 columns]

# %% [markdown]
# ### Section 2 - Slightly Deeper Look at Your Data

# %% [markdown]
# ##### Exercise 1
#
# How many `fran_id` are in `nba`?
#
# Hint, a dataframe column has the `.unique` method

# %%
# Out:
# 53

# %% [markdown]
# ##### Exercise 2
#
# Show number of rows per `fran_id` in `nba`?
#
# Hint, a dataframe column has the `.value_counts` method

# %%
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %% [markdown]
# ##### Exercise 3
#
# What was the first `date_game` the `fran_id` of "Lakers" play?
#
# Hint, a dataframe must be filtered, and then you can use the has the `.min` method on a specific column

# %%
# Out:
# '1/1/1949'

# %% [markdown]
# ##### Exercise 4
#
# What is the most recent `date_game` of `team_id` of "MNL"?
#
# Hint, a dataframe must be filtered, and then you can use the has the .max method on a specific column

# %%
# Out:
# '4/9/1959'

# %% [markdown]
# ##### Exercise 5
#
# In one command, show both the first date and most recent `date_game` of of `team_id` of "MNL"

# %%
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %% [markdown]
# ##### Exercise 6
#
# How many total `pts` did the `fran_id` of "Lakers" score if you added them from the entire dataset.
#
# Hint: consider how you must filter and aggregate.

# %%
# Out:
# 637444

# %% [markdown]
# ### Section 3 - Filtering Data and Aggregating By Groups

# %% [markdown]
# ##### Exercise 1
#
# Filter games for `year_id` greater than or equal to 2010, and show the mean number of `pts` per `year_id` for each `fran_id`. The `fran_id` should be shown as rows and the `year_id` should be columns.
#
#
# The cells inside the table can be interpreted as mean `pts` per `year_id` per `fran_id`.

# %%
# Out:
# year_id             2010        2011  ...        2014        2015
# fran_id                               ...
# Bucks          97.067416   91.878049  ...   95.475610   97.204545
# Bulls          97.448276   97.622449  ...   93.448276  100.180851
# Cavaliers     101.881720   95.451220  ...   98.219512  102.323529
# Celtics        98.009434   96.318681  ...   96.243902  101.058140
# Clippers       95.719512   98.646341  ...  108.042105  106.875000
# Grizzlies     102.487805   99.757895  ...   96.191011   97.892473
# Hawks         100.236559   93.882979  ...  100.325843  101.806122
# Heat           96.000000  100.165049  ...  101.225490   94.682927
# Hornets        94.825581   93.292683  ...   96.627907   94.158537
# Jazz          104.543478   99.426829  ...   95.012195   95.134146
# Kings         100.000000   99.402439  ...  100.500000  101.341463
# Knicks        102.109756  105.779070  ...   98.585366   91.890244
# Lakers        101.561905  100.576087  ...  102.951220   98.451220
# ...

# %% [markdown]
# ##### Exercise 2
#
# Filter your data where `fran_id` is either "Baltimore" or "Celtics" and the `pts` are 100 or more.
#
# Hint: to add more than one filter, you must consider the boolean logic.
#
# i.e. IF a == 10 OR b < 96, AND c == 'hello', THEN ....
#
# If I was dealing with the `nba` dataframe and had columns named `a, b, c` the previous statement would need parentheses along with boolean operators. These are `|` for OR and `&` for AND. Here's what it would look like for those columns and conditions:
#
# `nba[((nba['a'] == 10) | (nba['b'] < 96)) & (nba['c'] == 'hello')]  `

# %%
# Out:
#         gameorder       game_id lg_id  ...  game_result  forecast notes
# 951           476  194802050BLB   NBA  ...            W  0.867289   NaN
# 1415          708  194812300BLB   NBA  ...            W  0.498069   NaN
# 1487          744  194901120BLB   NBA  ...            W  0.593158   NaN
# 1683          842  194902170BLB   NBA  ...            L  0.843424   NaN
# 1725          863  194902250BOS   NBA  ...            W  0.598202   NaN
# ...           ...           ...   ...  ...          ...       ...   ...
# 125980      62991  201504040TOR   NBA  ...            W  0.282454   NaN
# 126019      63010  201504080DET   NBA  ...            W  0.384805   NaN
# 126076      63039  201504120BOS   NBA  ...            W  0.433403   NaN
# 126141      63071  201504150MIL   NBA  ...            W  0.448084   NaN
# 126162      63082  201504190CLE   NBA  ...            L  0.263276   NaN
#
# [3837 rows x 23 columns]

# %% [markdown]
# ##### Exercise 3
#
# Filter your data where `fran_id` is the "Spurs", the `year_id` is greater than 2010. Show the results grouped by `year_id` and `game_result` and show the number of games both won and lost.
#
# Hint: utilize filters and then use the `.groupby` method followed by selecting a column and using the `.count` method

# %%
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %% [markdown]
# ##### Exercise 4
#
# Ensure games where the `pts` and `opp_pts` wind up with the proper `game_result` corresponding to a win. Think through this, not immediately obvious.

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["game_result"] != 'W')]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes]
# Index: []

# %% [markdown]
# ### Section 4 - Manipulating Columns

# %% [markdown]
# ##### Exercise 1
#
# Create a new column (called "difference") that shows the difference between `pts` and `opp_pts`. Then display the dataframe `.head()`
#
# Hint: select each column separately and simply use a minus sign to find the difference.

# %%
# Out:
#    gameorder       game_id lg_id  ...  forecast  notes difference
# 0          1  194611010TRH   NBA  ...  0.640065    NaN         -2
# 1          1  194611010TRH   NBA  ...  0.359935    NaN          2
# 2          2  194611020CHS   NBA  ...  0.631101    NaN         16
# 3          2  194611020CHS   NBA  ...  0.368899    NaN        -16
# 4          3  194611020DTF   NBA  ...  0.640065    NaN        -17
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### Exercise 2
#
# Create a new dataframe called "renamed_nba" and rename the column "game_location" to "location". Then display the dataframe `.head()` (which should now contain a column "location" and no column named "game_location")
#
# Hint: remember that you can use the `.rename` method that takes a parameter `columns` in which you need to insert a dictionary.
#
# i.e. `.rename(columns={'': ''})`

# %%
# Out:
#    gameorder       game_id lg_id  ...  forecast  notes difference
# 0          1  194611010TRH   NBA  ...  0.640065    NaN         -2
# 1          1  194611010TRH   NBA  ...  0.359935    NaN          2
# 2          2  194611020CHS   NBA  ...  0.631101    NaN         16
# 3          2  194611020CHS   NBA  ...  0.368899    NaN        -16
# 4          3  194611020DTF   NBA  ...  0.640065    NaN        -17
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### Exercise 3
#
# From the `renamed_nba` dataframe created in the previous exercise, delete the column `seasongame`. Then display the `renamed_nba.head()` to ensure that this column is dropped "inplace"
#
# Hint: you can utilize the `.drop` method, you will need to add the parameter `axis=1` to the `.drop` method in order to make this happen.

# %%
# Out:
#    gameorder       game_id lg_id  ...  forecast  notes difference
# 0          1  194611010TRH   NBA  ...  0.640065    NaN         -2
# 1          1  194611010TRH   NBA  ...  0.359935    NaN          2
# 2          2  194611020CHS   NBA  ...  0.631101    NaN         16
# 3          2  194611020CHS   NBA  ...  0.368899    NaN        -16
# 4          3  194611020DTF   NBA  ...  0.640065    NaN        -17
#
# [5 rows x 23 columns]

# %% [markdown]
# ##### Exercise 4
#
# Change the data type (`dtype`) of the "gameorder" to a `float` in the `nba` dataframe. Utilize `nba.info()` to show that this change took place.
#
# Hint: use the `.astype` method

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  float64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# ### Section 5 - Handling Missing Values

# %% [markdown]
# ##### Exercise 1
# Show data filtering out `NaN` values in the "notes" column of `nba` data. (i.e. there should be no `NaN` in notes but there can be in other columns). Do not create a new dataframe.
#
# Hint: use the `.dropna` method, you will have to pass the parameter `subset` inside the method to ensure you only drop data from the `notes` column (and not all columns)

# %%
# Out:
#         gameorder  ... difference
# 930         466.0  ...        -24
# 931         466.0  ...         24
# 1084        543.0  ...         -4
# 1085        543.0  ...          4
# 1088        545.0  ...          3
# ...           ...  ...        ...
# 122207    61104.0  ...        -17
# 123916    61959.0  ...         12
# 123917    61959.0  ...        -12
# 124862    62432.0  ...         16
# 124863    62432.0  ...        -16
#
# [5424 rows x 24 columns]

# %% [markdown]
# ### Section 5 - Basic Plotting With Pandas

# %% [markdown]
# ##### Exercise 1
#
# Create a plot that shows the relationship of the average `pts` and `opp_pts` grouped by `year_id` and "fran_id".
#
# Hint: you'll need to take advantage of the methods:
#
# `.reset_index`
#
# `.groupby`
#
# `.mean`
#
# The attribute: `.plot`
#
# The `plot` method `.scatter` and pass in both an `x` and a `y` value

# %% [markdown]
# ##### Exercise 2
#
# Plot a line chart with `year_id` on the x-axis and average `pts` (per year) on the y-axis.
#
# Hint: consider the previous solution, but that you want a `line` instead of a `scatter` method.

# %% [markdown]
# ##### Exercise 3
#
# Create the same line chart as above, but change the line color to red.
#
# Hint: within `plot.line` method, you can pass another parameter `c` (after `x` and `y`) that can take the string `"red"` as a value to set the line color
