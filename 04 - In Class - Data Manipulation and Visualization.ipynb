# %% [markdown]
# # Pandas Review
#
# **Scenario:**
#
# You run a retail business. You have a dataset that has transaction data with fields:
#
#
#
# *   InvoiceNo - invoice number
# *   StockCode - product number
# *   Description - product description
# *   Quantity - number of units ordered
# *   InvoiceDate - invoice date
# *   UnitPrice - price per unit
# *   CustomerID - unique customer ID
# *   Country - country of the customer

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# ##### Exercise 1
# Import data from https://foco-ds-portal-files.s3.amazonaws.com/retail_data.csv

# %%
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %% [markdown]
# ##### Exercise 2
#
# Describe your data. Look at data types, null values, etc.

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240007 entries, 0 to 240006
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    240007 non-null  object
#  1   StockCode    240007 non-null  object
#  2   Description  239106 non-null  object
#  3   Quantity     240007 non-null  int64
#  4   InvoiceDate  240007 non-null  object
#  5   UnitPrice    240007 non-null  float64
#  6   CustomerID   172782 non-null  float64
#  7   Country      240007 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 14.6+ MB

# %% [markdown]
# ##### Exercise 3
#
# Convert `InvoiceDate` column to a `datetime64` type. You will need to use the `pd.to_datetime` method. After conversion, show the data type of the `InvoiceDate` column.
#
# Hint: `pd.to_datetime(dataframe['column'])`

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240007 entries, 0 to 240006
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    240007 non-null  object
#  1   StockCode    240007 non-null  object
#  2   Description  239106 non-null  object
#  3   Quantity     240007 non-null  int64
#  4   InvoiceDate  240007 non-null  datetime64[ns]
#  5   UnitPrice    240007 non-null  float64
#  6   CustomerID   172782 non-null  float64
#  7   Country      240007 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 14.6+ MB

# %% [markdown]
# ##### Exercise 4
#
# Now that you have a `datetime` column, you can create a new column for `year` and another for `month`. This will make grouping data easier later on. Go ahead and create columns for year and month.
#
# This can be done by using `.year` or `.month` function on the `InvoiceDate` column.
#
# In order to apply a function to all rows of a column, you must "map" a function to it. The easiest way to do it is by using a `lambda` function. These types of functions are short "one-liners" that do very simple operations.

# %%
# Out:
#   InvoiceNo StockCode  ...  year  month
# 0    536365    85123A  ...  2010     12
# 1    536365     71053  ...  2010     12
# 2    536365    84406B  ...  2010     12
# 3    536365    84029G  ...  2010     12
# 4    536365    84029E  ...  2010     12
#
# [5 rows x 10 columns]

# %% [markdown]
# ##### Exercise 5
#
# Create a `revenue` column, how should that be calculated?

# %%
# Out:
#   InvoiceNo StockCode  ... month  revenue
# 0    536365    85123A  ...    12    15.30
# 1    536365     71053  ...    12    20.34
# 2    536365    84406B  ...    12    22.00
# 3    536365    84029G  ...    12    20.34
# 4    536365    84029E  ...    12    20.34
#
# [5 rows x 11 columns]

# %% [markdown]
# ##### Exercise 6
#
# Create a new dataframe that totals the revenue by `year` and `month`. Use the `.reset_index` method to "ungroup" your data.

# %%
# Out:
#    year  month     revenue
# 0  2010     12  748957.020
# 1  2011      1  560000.260
# 2  2011      2  498062.650
# 3  2011      3  683267.080
# 4  2011      4  493207.121
# 5  2011      5  723333.510
# 6  2011      6  568316.290

# %% [markdown]
# ##### Exercise 7
#
# Create a line plot of your revenue over time by month for the year 2011.

# %% [markdown]
# ##### Exercise 8
#
# Create a new column `mom_change` that shows the month over month percent change in revenue.
#
# Hint: Use the `.pct_change` method
#
# Your result will have `NaN` in the `mom_change` column... what does this mean? Why does it happen?

# %%
# Out:
#    year  month     revenue  mom_change
# 0  2010     12  748957.020         NaN
# 1  2011      1  560000.260   -0.252293
# 2  2011      2  498062.650   -0.110603
# 3  2011      3  683267.080    0.371850
# 4  2011      4  493207.121   -0.278163

# %% [markdown]
# # Introduction to Data Visualization
#
# We will be utilizing the `seaborn` package. This is a package that works well with `pandas` to create beautiful data visualizations "out of the box".
#
# We will cover `matplotlib` later in this class. It is a very popular library and is the backbone of most data visualization libraries in Python. However, it is much more complicated and is not as easy to use.
#
#
# Why do we see `%matplotlib inline` everywhere!??! This has to do with Jupyter Notebooks. This is a magic command that is taken care of by Google Colab. If you do not use this command, plots do not show up in your notebook.
#
# Tutorials are fantastic for `seaborn` and can be located at: https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# ##### Exercise 1
#
# Import your `seaborn` package as `sns`.
#
# Note, in practice, ALL imports should happen in one code block at the top of your file. This way, everyone knows exactly what libraries are being used and aren't hunting through your code.

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ##### Exercise 2
#
# `seaborn` has some datasets for our benefit already built into the package. These are handy for teaching. These will not be used outside of learning, so it is not imperative to remember these commands.
#
# We create a dataframe of "iris" data. This famous dataset is used for classification of multiple iris species.
#
# This code is done for you...

# %%
iris = sns.load_dataset("iris") 
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##### Exercise 3
#
# Create a scatterplot for each combination of variables (except species) and then color the scatterplot points by species type. This gives us a nice overview of the relationships between variables and can lend some insight into how we may classify our data.
#
# This can be incredibly cumbersome to do by hand. We can utilize the `.pairplot` method from `sns` to do this quickly and easily (and it throws in a density plot as well).
#
# Take note of how long it takes to create this plot, you should certainly consider the amount of data you would ever be willing to put in here.

# %% [markdown]
# ##### Exercise 4
#
# `seaborn` can allow for different color schemes to be used in order for you to customize your plotting styles. Let's recreate the graph above after setting:
#
# `sns.set(color_codes=True)`
#
# Notes: This only needs to be done one time and should be done immediately after calling `import seaborn as sns` in order to be consistent throughout your notebook.

# %% [markdown]
# ##### Exercise 4
#
# We will load another pre-built dataset called "tips" from `sns`

# %%
tips = sns.load_dataset('tips') 
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ##### Exercise 5
#
# What would be a good way to try and visualize:
#
# `total_bill` split by `sex` and `day`?
#
# Hint: utilize the `.factorplot` method

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ##### Exercise 6
#
# How could we quickly create a scatterplot with `total_bill` on the x-axis and `tip` on the y-axis?
#
# What is this relationship suggesting?
#
# Would it make sense to add a regression line?
#
# Use `sns.regplot` to do this.

# %% [markdown]
# ##### Exercise 7
#
# Could you recreate the previous plot, but plot the points and lines as diffent colors based off of the `smoker` column?
