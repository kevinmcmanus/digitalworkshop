# %% [markdown]
# # Linear Regression by Hand
#
# Let's walk through building a linear regression "from scratch" The data is loaded for you below.
#
# You will be using `pandas` for dealing with the data, `altair` for data visualization.
#
# The `seaborn` library is ONLY being called to pull the `diamonds` dataset. You will not use it.
#
# For these exercises, USE the `data` variable, DO NOT USE the `diamonds` variable.

# %%
# DO NOT CHANGE ANYTHING IN THIS CODE BLOCK (even you Tom)
import pandas as pd
import seaborn as sns
import altair as alt

diamonds = sns.load_dataset('diamonds')
data = diamonds[(diamonds['x'] > 0) & (diamonds['z'] > 0)][['x','z']][0:5000]
data.columns = ['x', 'y']
data.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#       x     y
# 0  3.95  2.43
# 1  3.89  2.31
# 2  4.05  2.31
# 3  4.20  2.63
# 4  4.34  2.75

# %% [markdown]
# ## Exercise 1
#
# Create a scatterplot (remember, use `altair` only in this notebook for visualization)

# %%
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Exercise 2
#
# Use a `y = mx + b` style model, fit a line (roughly estimate the coefficients). Plot the previous chart and add a line over it. Leave the points blue but make the line red.
#
# You should call your new column `y_hat` ("hat" typically means "estimated")
#
# `data['y_hat'] = ________`

# %%
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Exercise 3
#
# Create a column to find the difference between `y` and `y_hat`. Call this column `difference`

# %% [markdown]
# ## Exercise 4
#
# Create a column `squared_difference` ... you should be able to figure out what this column stands for

# %% [markdown]
# ## Exercise 5
#
# Create variables for each of the following:
#
# *   `n` = `number of rows in data`
# *   `sum_x` = `sum(x)`
# *   `sum_y` = `sum(y)`
# *   `sum_x_times_y` = `sum( x * y)`
# *   `sum_x_times_sum_y` = `sum(x) * sum(y)`
# *   `squared_sum_x` = `sum(x^2)`
# *   `sum_x_squared` = `sum(x) ^ 2`

# %% [markdown]
# ## Exercise 6
#
# Create variables:
#
#
# *   `numerator` = `n*sum_x_times_y` - `sum_x_times_sum_y`
# *   `denominator` = `n*squared_sum_x` - `sum_x_squared`

# %% [markdown]
# ## Exercise 7
#
# Create variables:
#
# *   `m` = `numerator` / `denominator`
# *   `mean_x` = `mean(x)`
# *   `mean_y` = `mean(y)`
# *   `m_times_mean_x` = `m * mean_x`
# *   `b = mean_y - m_times_mean_x`

# %% [markdown]
# ## Exercise 8
#
# You have created `m` and `x` for your `y = mx + b` equation!
#
# `m = 0.6055684878546395`
#
# `b = 0.07614824145501276`
#
# Use these values to create a predicted line as you did in Exercise 2. Plot this line as you did in Exercise 2!

# %%
# Out:
# alt.LayerChart(...)
